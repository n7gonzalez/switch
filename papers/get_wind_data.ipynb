# %%
import rex

# %%
from rex import WindX
wtk_file = '/nrel/wtk/offshore_ca/Offshore_CA_2006.h5'
with WindX(wtk_file, hsds=True) as f:
    meta = f.meta
meta.to_csv("ca_region.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-04f4a457b077> in <module>
#       2 wtk_file = '/nrel/wtk/offshore_ca/Offshore_CA_2006.h5'
#       3 with WindX(wtk_file, hsds=True) as f:
# ----> 4     meta = f.meta
#       5 meta.to_csv("ca_region.csv")
#
# <ipython-input-8-04f4a457b077> in <module>
#       2 wtk_file = '/nrel/wtk/offshore_ca/Offshore_CA_2006.h5'
#       3 with WindX(wtk_file, hsds=True) as f:
# ----> 4     meta = f.meta
#       5 meta.to_csv("ca_region.csv")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/rex/resource_extraction/resource_extraction.py in meta(self)
#     217         meta : pandas.DataFrame
#     218         """
# --> 219         return self.resource.meta
#     220
#     221     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/rex/resource.py in meta(self)
#     782         if self._meta is None:
# ...

# %%
from rex import WindX

wtk_file = '/nrel/wtk/offshore_ca/Offshore_CA_2006.h5'
region=1
with WindX(wtk_file, hsds=True) as f:
    f.save_region("offshore_ca_2006.h5", region, datasets= 'windspeed_160m',region_col='offshore')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-ddec2447ddba> in <module>
#       4 region=1
#       5 with WindX(wtk_file, hsds=True) as f:
# ----> 6     f.save_region("offshore_ca_2006.h5", region, datasets= 'windspeed_160m',region_col='offshore')
#
# <ipython-input-4-ddec2447ddba> in <module>
#       4 region=1
#       5 with WindX(wtk_file, hsds=True) as f:
# ----> 6     f.save_region("offshore_ca_2006.h5", region, datasets= 'windspeed_160m',region_col='offshore')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/rex/resource_extraction/resource_extraction.py in save_region(self, out_fpath, region, datasets, region_col)
#    1496         gids = self.region_gids(region, region_col=region_col)
#    1497
# -> 1498         self.save_subset(out_fpath, gids, datasets=datasets)
#    1499
#    1500
#
# ...

# %%
from rex import WindX

wtk_file = '/nrel/wtk/nw_pacific/NW_Pacific_2006.h5'
region=1
with WindX(wtk_file, hsds=True) as f:
    f.save_region("nw_pacific_2006.h5", region, datasets= 'windspeed_160m',region_col='offshore')

# %%
f.save_region("nw_pacific_2006.h5", region, datasets= 'windspeed_160m',region_col='offshore')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-e4fe891266f7> in <module>
# ----> 1 f.save_region("nw_pacific_2006.h5", region, datasets= 'windspeed_160m',region_col='offshore')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/rex/resource_extraction/resource_extraction.py in save_region(self, out_fpath, region, datasets, region_col)
#    1496         gids = self.region_gids(region, region_col=region_col)
#    1497
# -> 1498         self.save_subset(out_fpath, gids, datasets=datasets)
#    1499
#    1500
#
# ~/opt/anaconda3/lib/python3.8/site-packages/rex/resource_extraction/resource_extraction.py in save_subset(self, out_fpath, gids, datasets)
#    1442
#    1443         datasets = self._get_datasets(datasets=datasets)
# -> 1444         with h5py.File(out_fpath, mode='w-') as f_out:
#    1445             for k, v in self.global_attrs.items():
# ...
