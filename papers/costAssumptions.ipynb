# %%
# Third-party packages
import matplotlib.pyplot as plt
from matplotlib import figure
import numpy as np
import pandas as pd

# %% [markdown]
# # Floating offshore wind

# %%
floating_cost_osw_advanced = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/cost_osw_advanced_floating.csv')
floating_cost_osw_conservative = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/cost_osw_conservative_floating.csv')
floating_cost_osw_moderate = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/cost_osw_moderate_floating.csv')
floating_cost_osw_very_advanced = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/cost_osw_very_advanced_floating.csv')
floating_cost_osw_very_conservative = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/cost_osw_very_conservative_floating.csv')

# %% [markdown]
# # Fixed Bottom Offshore Wind

# %%
fixed_cost_osw_advanced = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/cost_osw_advanced_fixed.csv')
fixed_cost_osw_conservative = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/cost_osw_conservative_fixed.csv')
fixed_cost_osw_moderate = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/cost_osw_moderate_fixed.csv')
fixed_cost_osw_very_advanced = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/cost_osw_very_advanced_fixed.csv')
fixed_cost_osw_very_conservative = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/cost_osw_very_conservative_fixed.csv')

# %%
fixed_cost_osw_moderate
# Out:
#     build_year  gen_fixed_om  gen_overnight_cost
# 0         2020   107125.3568         3485967.834
# 1         2021   102378.0440         3174943.423
# 2         2022    98695.2976         3025259.430
# 3         2023    95686.0720         2919056.442
# 4         2024    93141.8736         2836679.371
# 5         2025    90937.7984         2769372.449
# 6         2026    88994.1000         2712465.226
# 7         2027    87255.0520         2663170.421
# 8         2028    85682.2224         2619688.456
# 9         2029    84246.7872         2580793.350
# 10        2030    82925.6872         2545607.894
# 11        2031    81702.5888         2513486.428
# 12        2032    80564.0408         2483937.024
# 13        2033    79498.5136         2456579.205
# 14        2034    78498.3208         2431109.358
# 15        2035    77554.8152         2407284.400
# 16        2036    76662.2320         2384903.525
# 17        2037    75815.7672         2363802.435
# ...

# %%
advanced_wave_trend = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/advanced_wave_trend.csv')
conservative_wave_trend = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/conservative_wave_trend.csv')
moderate_wave_trend = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/moderate_wave_trend.csv')
very_advanced_wave_trend = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/very_advanced_wave_trend.csv')
very_conservative_wave_trend = pd.read_csv(r'/Users/nataliagonzalez/switch/notebooks_wave/files_for_cost_projections/very_conservative_wave_trend.csv')

# %%
advanced_wave_trend = advanced_wave_trend.drop(columns=['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6'])

# %%
advanced_wave_trend
# Out:
#     build_year  gen_fixed_om  gen_overnight_cost
# 0         2020      105400.0             3465000
# 1         2021      102328.4             3370087
# 2         2022       99256.8             3275174
# 3         2023       96185.2             3180261
# 4         2024       93113.6             3085348
# 5         2025       90042.0             2990435
# 6         2026       86970.4             2895522
# 7         2027       83898.8             2800609
# 8         2028       80827.2             2705697
# 9         2029       77755.6             2610784
# 10        2030       74684.0             2515871
# 11        2031       71612.4             2420958
# 12        2032       68540.8             2326045
# 13        2033       65469.2             2231132
# 14        2034       62397.6             2136219
# 15        2035       59326.0             2041306
# 16        2036       56254.4             1946393
# 17        2037       53182.8             1851480
# ...

# %% [markdown]
# # graphs

# %% [markdown]
# ### Wave O&M costs $/MW-yr

# %%
moderate_wave_trend
# Out:
#     build_year  gen_fixed_om  gen_overnight_cost
# 0         2020     105400.00           3465000.0
# 1         2021     102990.27           3374833.0
# 2         2022     100580.53           3284667.0
# 3         2023      98170.80           3194500.0
# 4         2024      95761.07           3104333.0
# 5         2025      93351.33           3014167.0
# 6         2026      90941.60           2924000.0
# 7         2027      88531.87           2833833.0
# 8         2028      86122.13           2743667.0
# 9         2029      83712.40           2653500.0
# 10        2030      81302.67           2563333.0
# 11        2031      78892.93           2473167.0
# 12        2032      76483.20           2383000.0
# 13        2033      74073.47           2292833.0
# 14        2034      71663.73           2202667.0
# 15        2035      69254.00           2112500.0
# 16        2036      66844.27           2022333.0
# 17        2037      64434.53           1932167.0
# ...

# %%
plt.figure(figsize=(8,6))
plt.plot(very_conservative_wave_trend['build_year'], very_conservative_wave_trend['gen_fixed_om']/1000, label="scenario 1")
plt.plot(conservative_wave_trend['build_year'], conservative_wave_trend['gen_fixed_om']/1000, label="scenario 2")
plt.plot(moderate_wave_trend['build_year'], moderate_wave_trend['gen_fixed_om']/1000, label="scenario 3")
plt.plot(advanced_wave_trend['build_year'], advanced_wave_trend['gen_fixed_om']/1000, label="scenario 4")
plt.plot(very_advanced_wave_trend['build_year'], very_advanced_wave_trend['gen_fixed_om']/1000, label="scenario 5")
#plt.title('Wave O&M Costs')
plt.xlabel('Year', fontsize='15')
plt.xticks(fontsize=15)
plt.ylabel('O&M Cost ($/kW-yr)', fontsize='15')
plt.yticks(fontsize=15)
plt.legend(fontsize='15')
plt.savefig('Wave O&M')

# %%
plt.figure(figsize=(8,6))
plt.plot(very_conservative_wave_trend['build_year'], very_conservative_wave_trend['gen_overnight_cost']/1000, label="scenario 1")
plt.plot(conservative_wave_trend['build_year'], conservative_wave_trend['gen_overnight_cost']/1000, label="scenario 2")
plt.plot(moderate_wave_trend['build_year'], moderate_wave_trend['gen_overnight_cost']/1000, label="scenario 3")
plt.plot(advanced_wave_trend['build_year'], advanced_wave_trend['gen_overnight_cost']/1000, label="scenario 4")
plt.plot(very_advanced_wave_trend['build_year'], very_advanced_wave_trend['gen_overnight_cost']/1000, label="scenario 5")
plt.xlabel('Year', fontsize='15')
plt.xticks(fontsize=15)
plt.ylabel('Overnight Cost ($/kW)', fontsize='15')
plt.yticks(fontsize=15)
plt.legend(fontsize='15')
plt.savefig('Wave overnight')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,6))

ax1.plot(very_conservative_wave_trend['build_year'], very_conservative_wave_trend['gen_overnight_cost']/1000, label="scenario 1")
ax1.plot(conservative_wave_trend['build_year'], conservative_wave_trend['gen_overnight_cost']/1000, label="scenario 2")
ax1.plot(moderate_wave_trend['build_year'], moderate_wave_trend['gen_overnight_cost']/1000, label="scenario 3")
ax1.plot(advanced_wave_trend['build_year'], advanced_wave_trend['gen_overnight_cost']/1000, label="scenario 4")
ax1.plot(very_advanced_wave_trend['build_year'], very_advanced_wave_trend['gen_overnight_cost']/1000, label="scenario 5")
ax1.set_title('Wave Overnight Costs', fontsize='15')
ax1.set_xlabel('Year', fontsize='15')
ax1.set_ylabel('Overnight Cost ($/kW)', fontsize='15')
ax1.tick_params(labelsize=15)

ax2.plot(very_conservative_wave_trend['build_year'], very_conservative_wave_trend['gen_fixed_om']/1000, label="scenario 1")
ax2.plot(conservative_wave_trend['build_year'], conservative_wave_trend['gen_fixed_om']/1000, label="scenario 2")
ax2.plot(moderate_wave_trend['build_year'], moderate_wave_trend['gen_fixed_om']/1000, label="scenario 3")
ax2.plot(advanced_wave_trend['build_year'], advanced_wave_trend['gen_fixed_om']/1000, label="scenario 4")
ax2.plot(very_advanced_wave_trend['build_year'], very_advanced_wave_trend['gen_fixed_om']/1000, label="scenario 5")
ax2.set_title('Wave O&M Costs', fontsize='15')
ax2.set_xlabel('Year', fontsize='15')
ax2.set_ylabel('O&M Cost ($/kW-yr)', fontsize='15')
ax2.tick_params(labelsize=15)

handles, labels = ax2.get_legend_handles_labels()
fig.legend(handles, labels, fontsize='15',loc='center right', bbox_to_anchor=(1.03, 0.5))

fig.savefig('results_v2/Wave cost projections', bbox_inches='tight')

# %%
plt.plot(fixed_cost_osw_very_conservative['build_year'], fixed_cost_osw_very_conservative['gen_fixed_om']/1000, label="scenario 1")
plt.plot(fixed_cost_osw_conservative['build_year'], fixed_cost_osw_conservative['gen_fixed_om']/1000, label="scenario 6")
plt.plot(fixed_cost_osw_moderate['build_year'], fixed_cost_osw_moderate['gen_fixed_om']/1000, label="scenario 11")
plt.plot(fixed_cost_osw_advanced['build_year'], fixed_cost_osw_advanced['gen_fixed_om']/1000, label="scenario 16")
plt.plot(fixed_cost_osw_very_advanced['build_year'], fixed_cost_osw_very_advanced['gen_fixed_om']/1000, label="scenario 21")
#plt.title('Offshore Wind Fixed O&M Costs')
plt.xlabel('Year')
plt.ylabel('Cost ($/kW-yr)')
plt.legend()
plt.savefig('OSW fixed O&M')

# %%
plt.plot(fixed_cost_osw_very_conservative['build_year'], fixed_cost_osw_very_conservative['gen_overnight_cost']/1000, label="scenario 1")
plt.plot(fixed_cost_osw_conservative['build_year'], fixed_cost_osw_conservative['gen_overnight_cost']/1000, label="scenario 6")
plt.plot(fixed_cost_osw_moderate['build_year'], fixed_cost_osw_moderate['gen_overnight_cost']/1000, label="scenario 11")
plt.plot(fixed_cost_osw_advanced['build_year'], fixed_cost_osw_advanced['gen_overnight_cost']/1000, label="scenario 16")
plt.plot(fixed_cost_osw_very_advanced['build_year'], fixed_cost_osw_very_advanced['gen_overnight_cost']/1000, label="scenario 21")
#plt.title('OSW Fixed Overnight Costs')
plt.xlabel('Year')
plt.ylabel('Cost ($/kW)')
plt.legend()
plt.savefig('OSW fixed overnight')

# %%
plt.plot(floating_cost_osw_very_conservative['build_year'], floating_cost_osw_very_conservative['gen_fixed_om']/1000, label="scenario 1")
plt.plot(floating_cost_osw_conservative['build_year'], floating_cost_osw_conservative['gen_fixed_om']/1000, label="scenario 6")
plt.plot(floating_cost_osw_moderate['build_year'], floating_cost_osw_moderate['gen_fixed_om']/1000, label="scenario 11")
plt.plot(floating_cost_osw_advanced['build_year'], floating_cost_osw_advanced['gen_fixed_om']/1000, label="scenario 16")
plt.plot(floating_cost_osw_very_advanced['build_year'], floating_cost_osw_very_advanced['gen_fixed_om']/1000, label="scenario 21")
#plt.title('OSW Float O&M Costs')
plt.xlabel('Year')
plt.ylabel('Cost ($/kW-yr)')
plt.legend()
plt.savefig('OSW float O&M')

# %%
plt.plot(floating_cost_osw_very_conservative['build_year'], floating_cost_osw_very_conservative['gen_overnight_cost']/1000, label="scenario 1")
plt.plot(floating_cost_osw_conservative['build_year'], floating_cost_osw_conservative['gen_overnight_cost']/1000, label="scenario 6")
plt.plot(floating_cost_osw_moderate['build_year'], floating_cost_osw_moderate['gen_overnight_cost']/1000, label="scenario 11")
plt.plot(floating_cost_osw_advanced['build_year'], floating_cost_osw_advanced['gen_overnight_cost']/1000, label="scenario 16")
plt.plot(floating_cost_osw_very_advanced['build_year'], floating_cost_osw_very_advanced['gen_overnight_cost']/1000, label="scenario 21")
#plt.title('OSW Float Overnight Costs')
plt.xlabel('Year')
plt.ylabel('Cost ($/kW)')
plt.legend()
plt.ticklabel_format(style='plain')
plt.savefig('OSW Float overnight')

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16,12))

ax1.plot(fixed_cost_osw_very_conservative['build_year'], fixed_cost_osw_very_conservative['gen_overnight_cost']/1000, label="scenario 1")
ax1.plot(fixed_cost_osw_conservative['build_year'], fixed_cost_osw_conservative['gen_overnight_cost']/1000, label="scenario 6")
ax1.plot(fixed_cost_osw_moderate['build_year'], fixed_cost_osw_moderate['gen_overnight_cost']/1000, label="scenario 11")
ax1.plot(fixed_cost_osw_advanced['build_year'], fixed_cost_osw_advanced['gen_overnight_cost']/1000, label="scenario 16")
ax1.plot(fixed_cost_osw_very_advanced['build_year'], fixed_cost_osw_very_advanced['gen_overnight_cost']/1000, label="scenario 21")
ax1.set_title('Fixed Offshore Wind Overnight Costs', fontsize='15')
ax1.set_xlabel('Year', fontsize='15')
ax1.set_ylabel('Cost ($/kW)', fontsize='15')
ax1.tick_params(labelsize=15)

ax2.plot(fixed_cost_osw_very_conservative['build_year'], fixed_cost_osw_very_conservative['gen_fixed_om']/1000, label="scenario 1")
ax2.plot(fixed_cost_osw_conservative['build_year'], fixed_cost_osw_conservative['gen_fixed_om']/1000, label="scenario 6")
ax2.plot(fixed_cost_osw_moderate['build_year'], fixed_cost_osw_moderate['gen_fixed_om']/1000, label="scenario 11")
ax2.plot(fixed_cost_osw_advanced['build_year'], fixed_cost_osw_advanced['gen_fixed_om']/1000, label="scenario 16")
ax2.plot(fixed_cost_osw_very_advanced['build_year'], fixed_cost_osw_very_advanced['gen_fixed_om']/1000, label="scenario 21")
ax2.set_title('Fixed Offshore Wind O&M Costs', fontsize='15')
ax2.set_xlabel('Year', fontsize='15')
ax2.set_ylabel('Cost ($/kW-yr)', fontsize='15')
ax2.tick_params(labelsize=15)

ax3.plot(floating_cost_osw_very_conservative['build_year'], floating_cost_osw_very_conservative['gen_overnight_cost']/1000, label="scenario 1")
ax3.plot(floating_cost_osw_conservative['build_year'], floating_cost_osw_conservative['gen_overnight_cost']/1000, label="scenario 6")
ax3.plot(floating_cost_osw_moderate['build_year'], floating_cost_osw_moderate['gen_overnight_cost']/1000, label="scenario 11")
ax3.plot(floating_cost_osw_advanced['build_year'], floating_cost_osw_advanced['gen_overnight_cost']/1000, label="scenario 16")
ax3.plot(floating_cost_osw_very_advanced['build_year'], floating_cost_osw_very_advanced['gen_overnight_cost']/1000, label="scenario 21")
ax3.set_title('Floating Offshore Wind Overnight Costs', fontsize='15')
ax3.set_xlabel('Year', fontsize='15')
ax3.set_ylabel('Cost ($/kW)', fontsize='15')
ax3.tick_params(labelsize=15)

ax4.plot(floating_cost_osw_very_conservative['build_year'], floating_cost_osw_very_conservative['gen_fixed_om']/1000, label="scenario 1")
ax4.plot(floating_cost_osw_conservative['build_year'], floating_cost_osw_conservative['gen_fixed_om']/1000, label="scenario 6")
ax4.plot(floating_cost_osw_moderate['build_year'], floating_cost_osw_moderate['gen_fixed_om']/1000, label="scenario 11")
ax4.plot(floating_cost_osw_advanced['build_year'], floating_cost_osw_advanced['gen_fixed_om']/1000, label="scenario 16")
ax4.plot(floating_cost_osw_very_advanced['build_year'], floating_cost_osw_very_advanced['gen_fixed_om']/1000, label="scenario 21")
ax4.set_title('Floating Offshore Wind O&M Costs', fontsize='15')
ax4.set_xlabel('Year', fontsize='15')
ax4.set_ylabel('Cost ($/kW-yr)', fontsize='15')
ax4.tick_params(labelsize=15)

handles, labels = ax4.get_legend_handles_labels()
fig.legend(handles, labels, fontsize='15',loc='center right', bbox_to_anchor=(1.13, 0.5))
fig.tight_layout()
fig.savefig('results_v2/OSW cost projections', bbox_inches='tight')
